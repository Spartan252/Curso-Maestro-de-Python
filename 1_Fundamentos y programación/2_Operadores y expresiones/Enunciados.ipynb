# %% [markdown]
# # Tema 02: Operadores y expresiones (Enunciados)
# *Nota: Estos ejercicios son optativos para hacer al final de la unidad y están pensados para apoyar tu aprendizaje*.

# %% [markdown]
# **1) Realiza un programa que lea 2 números por teclado y determine los siguientes aspectos (es suficiene con mostrar True o False):**
# * Si los dos números son iguales
# * Si los dos números son diferentes
# * Si el primero es mayor que el segundo
# * Si el segundo es mayor o igual que el primero

# %%
# Completa el ejercicio aquí
num_1 = float(input("Introduce el primer número: "))
num_2 = float(input("Introduce el segundo número: "))

print(f"El primer número es: {num_1}")
print(f"El segundo número es: {num_2}")

print(f"Los dos números son iguales?: {num_1 == num_2}")
print(f"Los dos números son diferentes?: {num_1 != num_2}")
print(f"El primer número es mayor que el segundo?: {num_1 > num_2}")
print(f"El segundo número es mayor o igual que el segundo?: {num_1 >= num_2}")
# Out:
# El primer número es: 23.0
# El segundo número es: 45.0
# Los dos números son iguales?: False
# Los dos números son diferentes?: True
# El primer número es mayor que el segundo?: False
# El segundo número es mayor o igual que el segundo?: False

# %% [markdown]
# **2) Utilizando operadores lógicos, determina si una cadena de texto introducida por el usuario tiene una longitud mayor o igual que 3 y a su vez es menor que 10 (es suficiene con mostrar True o False):**

# %%
# Completa el ejercicio aquí
cadena = input("Introduce una cadena de texto: ")

print(f"La cadena introducida es: {cadena}")
print(f"La cadena tiene una longitu mayor o igaul que 3 y a su vez menor que 10?: { len(cadena) >= 3 and len(cadena) < 10}")
# Out:
# La cadena introducida es: Pa
# La cadena tiene una longitu mayor o igaul que 3 y a su vez menor que 10?: False

# %% [markdown]
# **3) Realiza un programa que cumpla el siguiente algoritmo utilizando siempre que sea posible operadores en asignación:**
# * Guarda en una variable numero_magico el valor 12345679 (sin el 8)
# * Lee por pantalla otro numero_usuario, especifica que sea entre 1 y 9 (asegúrate que es un número)
# * Multiplica el numero_usuario por 9 en sí mismo
# * Multiplica el numero_magico por el numero_usuario en sí mismo
# * Finalmente muestra el valor final del numero_magico por pantalla

# %%
# Completa el ejercicio aquí

numero_magico = 12345679
numero_usuario = None

while not (isinstance(numero_usuario, (int, float)) and 1 <= numero_usuario <= 9):
    numero_usuario = float(input("Introduce un número del 1 al 9: "))

numero_usuario *= 9
print(f"El número introducido multiplicado por 9 es: {numero_usuario}")
numero_magico *= numero_usuario

print(f"El resultado es: {numero_magico}")
# Out:
# El número introducido multiplicado por 9 es: 54.0
# El resultado es: 666666666.0
